# %%
# !pip install pyqt5
# Out:
# Collecting pyqt5
#   Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl.metadata (2.1 kB)
# Collecting PyQt5-sip<13,>=12.15 (from pyqt5)
#   Downloading PyQt5_sip-12.17.0-cp39-cp39-win_amd64.whl.metadata (492 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyqt5)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    --------- ------------------------------ 1.6/6.9 MB 9.4 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.9 MB 7.7 MB/s eta 0:00:01
#    ------------------------ --------------- 4.2/6.9 MB 6.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.0/6.9 MB 6.3 MB/s eta 0:00:01
#    -------------------------------- ------- 5.5/6.9 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 4.7 MB/s  0:00:01
# Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#    ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#    ---------------------------------------- 0.5/50.1 MB 4.2 MB/s eta 0:00:12
#    - -------------------------------------- 1.3/50.1 MB 3.5 MB/s eta 0:00:14
#    - -------------------------------------- 2.1/50.1 MB 3.7 MB/s eta 0:00:14
#    -- ------------------------------------- 3.1/50.1 MB 4.0 MB/s eta 0:00:12
#    --- ------------------------------------ 4.5/50.1 MB 4.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 5.5/50.1 MB 4.6 MB/s eta 0:00:10
#    ----- ---------------------------------- 6.8/50.1 MB 4.8 MB/s eta 0:00:10
#    ----- ---------------------------------- 7.3/50.1 MB 4.7 MB/s eta 0:00:10
#    ------ --------------------------------- 7.9/50.1 MB 4.2 MB/s eta 0:00:11
#    ------ --------------------------------- 8.1/50.1 MB 4.0 MB/s eta 0:00:11
#    ------- -------------------------------- 9.2/50.1 MB 4.1 MB/s eta 0:00:11
#    ------- -------------------------------- 9.4/50.1 MB 4.0 MB/s eta 0:00:11
#    -------- ------------------------------- 10.2/50.1 MB 3.8 MB/s eta 0:00:11
#    --------- ------------------------------ 11.3/50.1 MB 3.9 MB/s eta 0:00:11
#    --------- ------------------------------ 12.1/50.1 MB 3.9 MB/s eta 0:00:10
#    ---------- ----------------------------- 13.1/50.1 MB 3.9 MB/s eta 0:00:10
#    ----------- ---------------------------- 13.9/50.1 MB 4.0 MB/s eta 0:00:10
#    ----------- ---------------------------- 14.9/50.1 MB 4.0 MB/s eta 0:00:09
#    ------------ --------------------------- 15.7/50.1 MB 4.0 MB/s eta 0:00:09
#    ------------- -------------------------- 16.8/50.1 MB 4.0 MB/s eta 0:00:09
#    -------------- ------------------------- 17.6/50.1 MB 4.0 MB/s eta 0:00:09
#    -------------- ------------------------- 18.6/50.1 MB 4.0 MB/s eta 0:00:08
#    --------------- ------------------------ 19.4/50.1 MB 4.0 MB/s eta 0:00:08
#    ---------------- ----------------------- 20.2/50.1 MB 4.0 MB/s eta 0:00:08
#    ---------------- ----------------------- 21.2/50.1 MB 4.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 21.8/50.1 MB 4.0 MB/s eta 0:00:08
#    ------------------ --------------------- 22.5/50.1 MB 4.0 MB/s eta 0:00:07
#    ------------------- -------------------- 23.9/50.1 MB 4.1 MB/s eta 0:00:07
#    -------------------- ------------------- 25.2/50.1 MB 4.1 MB/s eta 0:00:07
#    -------------------- ------------------- 25.7/50.1 MB 4.1 MB/s eta 0:00:06
#    --------------------- ------------------ 26.7/50.1 MB 4.1 MB/s eta 0:00:06
#    --------------------- ------------------ 27.5/50.1 MB 4.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 28.0/50.1 MB 4.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 28.6/50.1 MB 4.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 29.1/50.1 MB 4.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 29.6/50.1 MB 3.9 MB/s eta 0:00:06
#    ------------------------ --------------- 30.1/50.1 MB 3.9 MB/s eta 0:00:06
#    ------------------------ --------------- 31.2/50.1 MB 3.9 MB/s eta 0:00:05
#    ------------------------- -------------- 32.0/50.1 MB 3.9 MB/s eta 0:00:05
#    ------------------------- -------------- 32.5/50.1 MB 3.9 MB/s eta 0:00:05
#    -------------------------- ------------- 32.8/50.1 MB 3.8 MB/s eta 0:00:05
#    -------------------------- ------------- 33.3/50.1 MB 3.8 MB/s eta 0:00:05
#    --------------------------- ------------ 34.3/50.1 MB 3.8 MB/s eta 0:00:05
#    ---------------------------- ----------- 35.7/50.1 MB 3.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 37.0/50.1 MB 3.9 MB/s eta 0:00:04
#    ------------------------------ --------- 38.0/50.1 MB 3.9 MB/s eta 0:00:04
#    ------------------------------ --------- 38.5/50.1 MB 3.9 MB/s eta 0:00:03
#    ------------------------------- -------- 39.6/50.1 MB 3.9 MB/s eta 0:00:03
#    -------------------------------- ------- 40.1/50.1 MB 3.9 MB/s eta 0:00:03
#    -------------------------------- ------- 40.9/50.1 MB 3.9 MB/s eta 0:00:03
#    --------------------------------- ------ 41.9/50.1 MB 3.9 MB/s eta 0:00:03
#    ---------------------------------- ----- 42.7/50.1 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 43.5/50.1 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 44.0/50.1 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 44.3/50.1 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------ --- 45.1/50.1 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------ --- 46.1/50.1 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 46.9/50.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 47.4/50.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 48.5/50.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  49.8/50.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 50.1/50.1 MB 3.8 MB/s  0:00:13
# Downloading PyQt5_sip-12.17.0-cp39-cp39-win_amd64.whl (59 kB)
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, pyqt5
#
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    ---------------------------------------- 0/3 [PyQt5-Qt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    -------------------------- ------------- 2/3 [pyqt5]
#    ---------------------------------------- 3/3 [pyqt5]
#
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.17.0 pyqt5-5.15.11

# %%
# 나만의 어플리케이션 만들어 보자
from PyQt5.QtWidgets import QApplication, QWidget
import sys # 해당 App을 우리 윈도우에 띄우기 위해

# 처음부터 구현하지 않고 QWudge 상속 받아서 만들자
class MyApp(QWidget):
    def __init__(self):
        # 부모 안에 있는 field 가져다 쓰자
        super().__init__()
        self.initUI()

    # 초기 화면 구성
    def initUI(self):
        self.setWindowTitle("exam01")
        self.move(1000, 500)
        self.resize(400, 200) # width * height (pixel)
        self.show()

if __name__ == "__main__":
    # 내가 직접 실행했을 때만 실행되는 부분
    # 현재 동작하고 있는 App을 띄우기 위한 인스턴스가 있는지 여부
    app = QApplication.instance()
    if app is None:
        app = QApplication(sys.argv) # 윈도우 시스템에 띄우기 위해
    exam = MyApp()
    sys.exit(app.exec_()) # 윈도우 창이 꺼지면 app도 없애버리자
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton
import sys 

class MyApp(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()

    # 초기 화면 구성
    def initUI(self):
        self.setWindowTitle("exam02")
        self.setGeometry(100, 500, 400, 200) # move, resize 한 번에
        button = QPushButton("눌러봐잇", self) # (문구, 부모)
        button.move(50, 70) # 왼쪽 상단 기준 얼마나 떨어져 있을지
        button.resize(100, 50)
        button.resize(button.sizeHint()) # 버튼 사이즈 알아서 추천

        # 버튼을 눌렀을 때 실행되는 함수 정의
        def set_color():
            self.setStyleSheet("background-color : #FF0000")
            button.setText("바보 ㅋㅋ")
        button.clicked.connect(set_color)

        # 버튼을 눌렀을 때 실행되는 함수 정의
        # 이렇게 정의 된 함수는 한 번만 쓰이니까
        # 정의하지 말고 바로 쓰자 -> lambda expression
        # df.apply(타이타닉 Sex Female -> 1, 0)
        button.pressed.connect(lambda : self.setStyleSheet("background-color: #F86796"))
        button.released.connect(lambda : self.setStyleSheet("background-color: #0000FF"))
        
        self.show()

if __name__ == "__main__":
    app = QApplication.instance()
    if app is None:
        app = QApplication(sys.argv)
    exam = MyApp()
    sys.exit(app.exec_())
if __name__ == "__main__":
    app = QApplication.instance()
    if app is None:
        app = QApplication(sys.argv) 
    exam = MyApp()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
from PyQt5.QtWidgets import (
                        QApplication, QWidget, QLineEdit, QPushButton, QLabel,
                        QRadioButton, QCheckBox, QVBoxLayout, QHBoxLayout
)
import sys

class MyApp(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()

    # 초기화면 구성
    def initUI(self):
        self.setWindowTitle("exam03")
        self.setGeometry(100, 500, 400, 200) # move, resize 한 번에
        
        qle_id = QLineEdit(self)
        qle_pw = QLineEdit(self)

        btn_login = QPushButton("로그인", self)

        qle_id.setGeometry(50, 50, 200, 25)
        qle_id.setPlaceholderText("ID를 입력하세요")
        qle_pw.setGeometry(50, 100, 200, 25)
        qle_pw.setPlaceholderText("PW를 입력하세요")
        qle_pw.setEchoMode(QLineEdit.Password)
        btn_login.setGeometry(100, 150, 100, 25)

        def login():
            # qle_id에 있는 문자열 정보 받아오고
            # qle_pw에 있는 문자열 가져오고
            login_id = qle_id.text()
            login_pw = qle_pw.text()
            if login_id == "hannaya" and login_pw == "1212":
                self.setStyleSheet("background-color: #FF0000")
            else:
                self.setStyleSheet("background-color: #0000FF")

        btn_login.clicked.connect(login)
        self.show()

if __name__ == "__main__":
    app = QApplication.instance()
    if app is None:
        app = QApplication(sys.argv)
    exam = MyApp()
    sys.exit(app.exec_())

# %%
from PyQt5.QtCore import Qt
from PyQt5.QtWidgets import (
                        QApplication, QWidget, QLineEdit, QPushButton, QLabel,
                        QRadioButton, QCheckBox, QVBoxLayout, QHBoxLayout
)
from PyQt5.QtGui import QPixmap
import sys

class MyApp(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()

    # 초기화면 구성
    def initUI(self):
        self.setWindowTitle("exam04")
        self.setGeometry(800, 300, 400, 600) # move, resize 한 번에
        # 수직 Box
        #  - 위젯
        #  - 수평 Box
        #  - - 버튼1, 버튼2
        vbox = QVBoxLayout()
        vbox.addStretch(1)
        self.ql = QLabel("연습용", alignment=Qt.AlignCenter)

        # 이미지 로드
        self.idx = 0
        path = f"imgs/img{self.idx + 1}.jpeg"
        qpm = QPixmap(path)
        qpm = qpm.scaled(400, 400)
        self.ql.setPixmap(qpm)
        

        def next_img():
            self.idx += 1
            if self.idx >= 5:
                self.idx = 0
            path = f"imgs/img{self.idx + 1}.jpeg"
            qpm = QPixmap(path)
            qpm = qpm.scaled(400, 400)
            self.ql.setPixmap(qpm)
        def prev_img():
            self.idx -= 1
            if self.idx  < 0:
                self.idx = 4
            path = f"imgs/img{self.idx + 1}.jpeg"
            qpm = QPixmap(path)
            qpm = qpm.scaled(400, 400)
            self.ql.setPixmap(qpm)
        
        vbox.addWidget(self.ql)
        vbox.addStretch(1)

        hbox = QHBoxLayout()
        btn1 = QPushButton("<")
        btn1.setStyleSheet("background-color:#CC99FF")
        btn1.clicked.connect(prev_img)
        btn2 = QPushButton(">")
        btn2.setStyleSheet("background-color:#CC99FF")
        btn2.clicked.connect(next_img)
        hbox.addStretch(1)
        vbox.setSpacing(40)
        
        
        hbox.addWidget(btn1)
        hbox.addWidget(btn2)
        hbox.addStretch(1)

        vbox.addLayout(hbox)
        vbox.addStretch(1)

        self.setLayout(vbox)
        
        self.show()

if __name__ == "__main__":
    app = QApplication.instance()
    if app is None:
        app = QApplication(sys.argv)
    exam = MyApp()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
# !pyinstaller --onefile game.py
# Out:
# 51 DEPRECATION: Running PyInstaller as admin is not necessary nor sensible. Run PyInstaller from a non-administrator terminal. PyInstaller 7.0 will block this.
# 536 INFO: PyInstaller: 6.15.0, contrib hooks: 2025.8
# 536 INFO: Python: 3.9.23 (conda)
# 549 INFO: Platform: Windows-10-10.0.26100-SP0
# 549 INFO: Python environment: C:\ProgramData\anaconda3\envs\myenv
# 549 INFO: wrote C:\Users\KCCISTC\Desktop\workspace\game.spec
# 560 INFO: Module search paths (PYTHONPATH):
# ['C:\\ProgramData\\anaconda3\\envs\\myenv\\Scripts\\pyinstaller.exe',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\python39.zip',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\DLLs',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\setuptools\\_vendor',
#  'C:\\Users\\KCCISTC\\Desktop\\workspace']
# 1419 INFO: checking Analysis
# 1419 INFO: Building Analysis because Analysis-00.toc is non existent
# 1419 INFO: Running Analysis Analysis-00.toc
# 1419 INFO: Target bytecode optimization level: 0
# 1419 INFO: Initializing module dependency graph...
# 1419 INFO: Initializing module graph hook caches...
# 1457 INFO: Analyzing modules for base_library.zip ...
# 2987 INFO: Processing standard module hook 'hook-heapq.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks'
# 3077 INFO: Processing standard module hook 'hook-encodings.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks'
# 4846 INFO: Processing standard module hook 'hook-pickle.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks'
# 5859 INFO: Caching module dependency graph...
# 5920 INFO: Looking for Python shared library...
# 5920 INFO: Using Python shared library: C:\ProgramData\anaconda3\envs\myenv\python39.dll
# 5920 INFO: Analyzing C:\Users\KCCISTC\Desktop\workspace\game.py
# 5936 INFO: Processing standard module hook 'hook-PyQt5.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks'
# 6560 INFO: Processing standard module hook 'hook-PyQt5.QtCore.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks'
# 7466 INFO: Processing standard module hook 'hook-PyQt5.QtWidgets.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks'
# 8293 INFO: Processing standard module hook 'hook-PyQt5.QtGui.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks'
# 8752 INFO: Processing module hooks (post-graph stage)...
# 8767 WARNING: Hidden import "sip" not found!
# 8926 INFO: Performing binary vs. data reclassification (97 entries)
# 8989 INFO: Looking for ctypes DLLs
# 8989 INFO: Analyzing run-time hooks ...
# 8989 INFO: Including run-time hook 'pyi_rth_pyqt5.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 8989 INFO: Processing pre-find-module-path hook 'hook-_pyi_rth_utils.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 8989 INFO: Processing standard module hook 'hook-_pyi_rth_utils.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks'
# 8989 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 9005 INFO: Including run-time hook 'pyi_rth_inspect.py' from 'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 9005 INFO: Creating base_library.zip...
# 9100 INFO: Looking for dynamic libraries
# 9211 INFO: Extra DLL search directories (AddDllDirectory): ['C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\PyQt5\\Qt5\\bin']
# 9211 INFO: Extra DLL search directories (PATH): []
# 10890 INFO: Warnings written to C:\Users\KCCISTC\Desktop\workspace\build\game\warn-game.txt
# 10913 INFO: Graph cross-reference written to C:\Users\KCCISTC\Desktop\workspace\build\game\xref-game.html
# 10937 INFO: checking PYZ
# 10937 INFO: Building PYZ because PYZ-00.toc is non existent
# 10937 INFO: Building PYZ (ZlibArchive) C:\Users\KCCISTC\Desktop\workspace\build\game\PYZ-00.pyz
# 11261 INFO: Building PYZ (ZlibArchive) C:\Users\KCCISTC\Desktop\workspace\build\game\PYZ-00.pyz completed successfully.
# 11273 INFO: checking PKG
# 11273 INFO: Building PKG because PKG-00.toc is non existent
# 11273 INFO: Building PKG (CArchive) game.pkg
# 24402 INFO: Building PKG (CArchive) game.pkg completed successfully.
# 24402 INFO: Bootloader C:\ProgramData\anaconda3\envs\myenv\lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\run.exe
# 24402 INFO: checking EXE
# 24402 INFO: Building EXE because EXE-00.toc is non existent
# 24402 INFO: Building EXE from EXE-00.toc
# 24402 INFO: Copying bootloader EXE to C:\Users\KCCISTC\Desktop\workspace\dist\game.exe
# 24418 INFO: Copying icon to EXE
# 24418 INFO: Copying 0 resources to EXE
# 24418 INFO: Embedding manifest in EXE
# 24418 INFO: Appending PKG archive to EXE
# 24466 INFO: Fixing EXE headers
# 24783 INFO: Building EXE from EXE-00.toc completed successfully.
# 24783 INFO: Build complete! The results are available in: C:\Users\KCCISTC\Desktop\workspace\dist

# %%
# !pip install pyinstaller
# Out:
# Collecting pyinstaller
#   Downloading pyinstaller-6.15.0-py3-none-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: setuptools>=42.0.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from pyinstaller) (78.1.1)
# Collecting altgraph (from pyinstaller)
#   Downloading altgraph-0.17.4-py2.py3-none-any.whl.metadata (7.3 kB)
# Collecting pefile!=2024.8.26,>=2022.5.30 (from pyinstaller)
#   Downloading pefile-2023.2.7-py3-none-any.whl.metadata (1.4 kB)
# Collecting pywin32-ctypes>=0.2.1 (from pyinstaller)
#   Downloading pywin32_ctypes-0.2.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting pyinstaller-hooks-contrib>=2025.8 (from pyinstaller)
#   Downloading pyinstaller_hooks_contrib-2025.8-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: importlib_metadata>=4.6 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from pyinstaller) (8.7.0)
# Requirement already satisfied: packaging>=22.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from pyinstaller) (25.0)
# Requirement already satisfied: zipp>=3.20 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from importlib_metadata>=4.6->pyinstaller) (3.23.0)
# Downloading pyinstaller-6.15.0-py3-none-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 10.2 MB/s  0:00:00
# Downloading pefile-2023.2.7-py3-none-any.whl (71 kB)
# Downloading pyinstaller_hooks_contrib-2025.8-py3-none-any.whl (442 kB)
# Downloading pywin32_ctypes-0.2.3-py3-none-any.whl (30 kB)
# Downloading altgraph-0.17.4-py2.py3-none-any.whl (21 kB)
# Installing collected packages: altgraph, pywin32-ctypes, pefile, pyinstaller-hooks-contrib, pyinstaller
#
#    -------- ------------------------------- 1/5 [pywin32-ctypes]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    ------------------------ --------------- 3/5 [pyinstaller-hooks-contrib]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    -------------------------------- ------- 4/5 [pyinstaller]
#    ---------------------------------------- 5/5 [pyinstaller]
#
# Successfully installed altgraph-0.17.4 pefile-2023.2.7 pyinstaller-6.15.0 pyinstaller-hooks-contrib-2025.8 pywin32-ctypes-0.2.3
